# %% [markdown]
# #### Data was released Mar 29. Before summer uptick.
# #### SQL query below to extract and format data correctly
#
# `SELECT DISTINCT l.zip, l.county, p.person_id, p.gender_source_value, p.birth_datetime, p.death_datetime, p.race_source_value, p.ethnicity_source_value, c.condition_start_datetime, c.condition_concept_id
# FROM person p
# INNER JOIN condition_occurrence c ON c.person_id = p.person_id
# INNER JOIN location l on l.location_id = p.location_id
# WHERE condition_concept_id = '37311061' --Disease caused by 2019-nCoV`

# %%
import pandas as pd

#data contains positive cases, gender, race/ethnicity, death, birth
data = pd.read_csv ('data-1605136079581.csv')
pop = pd.read_csv ('population2010.csv')

# %%
#remove the word 'county' from the county column
data['county'] = data['county'].str.split(' ').str[0]
data['condition_month'] = pd.DatetimeIndex(data['condition_start_datetime']).month
data['condition_day'] = pd.DatetimeIndex(data['condition_start_datetime']).day
death = data [data['death_datetime'].notna()]
data
# Out:
#          zip     county  person_id gender_source_value       birth_datetime  \
# 0        NaN  Worcester       8573                   F  1959-06-24 00:00:00
# 1     1810.0      Essex       3432                   F  1966-04-01 00:00:00
# 2     2301.0   Plymouth       8285                   M  1948-10-18 00:00:00
# 3     2457.0    Norfolk       8741                   F  1991-08-28 00:00:00
# 4     2110.0    Suffolk       7577                   M  2002-12-31 00:00:00
# ...      ...        ...        ...                 ...                  ...
# 1900  1983.0      Essex      10536                   F  1976-07-25 00:00:00
# 1901     NaN    Hampden      11130                   M  1973-10-04 00:00:00
# 1902     NaN  Worcester       3746                   F  2002-12-21 00:00:00
# 1903  2121.0    Suffolk       7880                   F  1951-01-13 00:00:00
# 1904  2790.0    Bristol       1371                   F  1996-03-16 00:00:00
#
#            death_datetime race_source_value ethnicity_source_value  \
# 0                     NaN             black               hispanic
# 1     2020-03-03 00:00:00             black            nonhispanic
# 2                     NaN             white            nonhispanic
# 3     2020-02-17 00:00:00             white            nonhispanic
# 4                     NaN             white            nonhispanic
# ...                   ...               ...                    ...
# 1900                  NaN             white            nonhispanic
# 1901                  NaN             white            nonhispanic
# 1902                  NaN             black            nonhispanic
# 1903  2020-02-15 00:00:00             asian            nonhispanic
# 1904                  NaN             white               hispanic
#
#      condition_start_datetime  condition_concept_id  condition_month  \
# 0         2020-02-20 00:00:00              37311061                2
# 1         2020-02-04 00:00:00              37311061                2
# 2         2020-02-14 00:00:00              37311061                2
# 3         2020-01-27 00:00:00              37311061                1
# 4         2020-03-15 00:00:00              37311061                3
# ...                       ...                   ...              ...
# 1900      2020-03-22 00:00:00              37311061                3
# 1901      2020-03-05 00:00:00              37311061                3
# 1902      2020-01-07 00:00:00              37311061                1
# 1903      2020-02-10 00:00:00              37311061                2
# 1904      2020-03-27 00:00:00              37311061                3
#
#       condition_day
# 0                20
# 1                 4
# 2                14
# 3                27
# 4                15
# ...             ...
# 1900             22
# 1901              5
# 1902              7
# 1903             10
# 1904             27
#
# [1905 rows x 12 columns]

# %%
#cases by county
#some persons have multiple entries (unique cases)
data_pos = data.groupby(['county', 'condition_month','condition_day','gender_source_value','race_source_value', 'ethnicity_source_value']).size().reset_index(name='positive_counts')

data_death = death.groupby(['county', 'condition_month', 'condition_day','gender_source_value','race_source_value', 'ethnicity_source_value']).size().reset_index(name='death_counts')

# %%
data_flat = pd.merge (data_pos, data_death, on = ['county', 'condition_month', 'condition_day','gender_source_value', 'race_source_value','ethnicity_source_value'], how="outer")

# %%
data_flat_pop_fips = pd.merge (data_flat, pop, on = ['county'])
data_flat_pop_fips
# Out:
#           county  condition_month  condition_day gender_source_value  \
# 0     Barnstable                1              6                   M
# 1     Barnstable                1              8                   F
# 2     Barnstable                1             12                   F
# 3     Barnstable                1             13                   F
# 4     Barnstable                1             13                   M
# ...          ...              ...            ...                 ...
# 1348   Worcester                3             23                   M
# 1349   Worcester                3             25                   F
# 1350   Worcester                3             25                   M
# 1351   Worcester                3             26                   F
# 1352   Worcester                3             26                   M
#
#      race_source_value ethnicity_source_value  positive_counts  death_counts  \
# 0                white            nonhispanic                2           1.0
# 1                white            nonhispanic                1           1.0
# 2                white            nonhispanic                1           NaN
# 3                white            nonhispanic                1           NaN
# 4                white            nonhispanic                2           2.0
# ...                ...                    ...              ...           ...
# 1348             white            nonhispanic                1           NaN
# 1349             white            nonhispanic                1           NaN
# 1350             black               hispanic                1           NaN
# 1351             white            nonhispanic                1           NaN
# 1352             white            nonhispanic                2           NaN
#
#       fips_code  population_2010
# 0         25001           215888
# 1         25001           215888
# 2         25001           215888
# 3         25001           215888
# 4         25001           215888
# ...         ...              ...
# 1348      25027           798552
# 1349      25027           798552
# 1350      25027           798552
# 1351      25027           798552
# 1352      25027           798552
#
# [1353 rows x 10 columns]

# %%
data_flat_pop_fips.to_csv('covid_ma_positive_death_counts.csv', sep = ',')
